# %%
import pandas as pd
data = pd.read_csv('gapminder.csv')

# %%
data.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %% [markdown]
# ### Using the  𝑔𝑎𝑝𝑚𝑖𝑛𝑑𝑒𝑟  data For each year in our data, what is the average life expectancy, average population, and average GDP?

# %% [markdown]
# ##### Calculating the average life expectancy for each year

# %%
data.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %% [markdown]
# ##### Calculating the average population for each year

# %%
data.groupby('year')['pop'].mean()
# Out:
# year
# 1952    1.695040e+07
# 1957    1.876341e+07
# 1962    2.042101e+07
# 1967    2.265830e+07
# 1972    2.518998e+07
# 1977    2.767638e+07
# 1982    3.020730e+07
# 1987    3.303857e+07
# 1992    3.599092e+07
# 1997    3.883947e+07
# 2002    4.145759e+07
# 2007    4.402122e+07
# Name: pop, dtype: float64

# %% [markdown]
# ##### Calculating the average life GDP for each year

# %%
data.groupby('year')['gdpPercap'].mean()
# Out:
# year
# 1952     3725.276046
# 1957     4299.408345
# 1962     4725.812342
# 1967     5483.653047
# 1972     6770.082815
# 1977     7313.166421
# 1982     7518.901673
# 1987     7900.920218
# 1992     8158.608521
# 1997     9090.175363
# 2002     9917.848365
# 2007    11680.071820
# Name: gdpPercap, dtype: float64

# %% [markdown]
# ### Find the average life expectancy and average GDP for  𝐴𝑚𝑒𝑟𝑖𝑐𝑎𝑠  for the year 2002

# %%
data.groupby('continent').nunique()
# Out:
#            country  year  lifeExp  pop  gdpPercap
# continent
# Africa          52    12      619  624        624
# Americas        25    12      299  300        300
# Asia            33    12      393  396        396
# Europe          30    12      326  360        360
# Oceania          2    12       24   24         24

# %%
data.groupby(['year','continent'])['lifeExp'].mean()
# Out:
# year  continent
# 1952  Africa       39.135500
#       Americas     53.279840
#       Asia         46.314394
#       Europe       64.408500
#       Oceania      69.255000
# 1957  Africa       41.266346
#       Americas     55.960280
#       Asia         49.318544
#       Europe       66.703067
#       Oceania      70.295000
# 1962  Africa       43.319442
#       Americas     58.398760
#       Asia         51.563223
#       Europe       68.539233
#       Oceania      71.085000
# 1967  Africa       45.334538
#       Americas     60.410920
#       Asia         54.663640
#       Europe       69.737600
#       Oceania      71.310000
# 1972  Africa       47.450942
#       Americas     62.394920
#       Asia         57.319269
#       Europe       70.775033
#       Oceania      71.910000
# 1977  Africa       49.580423
#       Americas     64.391560
#       Asia         59.610556
#       Europe       71.937767
#       Oceania      72.855000
# 1982  Africa       51.592865
# ...

# %%
data.groupby(['year','continent'])['gdpPercap'].mean()
# Out:
# year  continent
# 1952  Africa        1252.572466
#       Americas      4079.062552
#       Asia          5195.484004
#       Europe        5661.057435
#       Oceania      10298.085650
# 1957  Africa        1385.236062
#       Americas      4616.043733
#       Asia          5787.732940
#       Europe        6963.012816
#       Oceania      11598.522455
# 1962  Africa        1598.078825
#       Americas      4901.541870
#       Asia          5729.369625
#       Europe        8365.486814
#       Oceania      12696.452430
# 1967  Africa        2050.363801
#       Americas      5668.253496
#       Asia          5971.173374
#       Europe       10143.823757
#       Oceania      14495.021790
# 1972  Africa        2339.615674
#       Americas      6491.334139
#       Asia          8187.468699
#       Europe       12479.575246
#       Oceania      16417.333380
# 1977  Africa        2585.938508
#       Americas      7352.007126
#       Asia          7791.314020
# ...

# %%
olympics =  pd.read_csv('olympics.csv')
olympics.head()
# Out:
#   List of medallists at the Games of the Olympiad per edition, sport, discipline, gender and event  \
# 0                                                NaN
# 1  DISCLAIMER: The IOC Research and Reference Ser...
# 2                                                NaN
# 3                                               City
# 4                                             Athens
#
#   Unnamed: 1 Unnamed: 2  Unnamed: 3     Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN         NaN            NaN        NaN        NaN
# 1        NaN        NaN         NaN            NaN        NaN        NaN
# 2        NaN        NaN         NaN            NaN        NaN        NaN
# 3    Edition      Sport  Discipline        Athlete        NOC     Gender
# 4       1896   Aquatics    Swimming  HAJOS, Alfred        HUN        Men
#
#        Unnamed: 7    Unnamed: 8 Unnamed: 9
# 0             NaN           NaN        NaN
# 1             NaN           NaN        NaN
# ...

# %%
oil = olympics.copy()
oil.head()
# Out:
#   List of medallists at the Games of the Olympiad per edition, sport, discipline, gender and event  \
# 0                                                NaN
# 1  DISCLAIMER: The IOC Research and Reference Ser...
# 2                                                NaN
# 3                                               City
# 4                                             Athens
#
#   Unnamed: 1 Unnamed: 2  Unnamed: 3     Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN         NaN            NaN        NaN        NaN
# 1        NaN        NaN         NaN            NaN        NaN        NaN
# 2        NaN        NaN         NaN            NaN        NaN        NaN
# 3    Edition      Sport  Discipline        Athlete        NOC     Gender
# 4       1896   Aquatics    Swimming  HAJOS, Alfred        HUN        Men
#
#        Unnamed: 7    Unnamed: 8 Unnamed: 9
# 0             NaN           NaN        NaN
# 1             NaN           NaN        NaN
# ...

# %%
oil.columns = oil.iloc[3]

# %%
oil.head()
# Out:
# 3                                               City  Edition     Sport  \
# 0                                                NaN      NaN       NaN
# 1  DISCLAIMER: The IOC Research and Reference Ser...      NaN       NaN
# 2                                                NaN      NaN       NaN
# 3                                               City  Edition     Sport
# 4                                             Athens     1896  Aquatics
#
# 3  Discipline        Athlete  NOC  Gender           Event  Event_gender  Medal
# 0         NaN            NaN  NaN     NaN             NaN           NaN    NaN
# 1         NaN            NaN  NaN     NaN             NaN           NaN    NaN
# 2         NaN            NaN  NaN     NaN             NaN           NaN    NaN
# 3  Discipline        Athlete  NOC  Gender           Event  Event_gender  Medal
# 4    Swimming  HAJOS, Alfred  HUN     Men  100m freestyle             M   Gold

# %%
oil.drop([0,1,2,3],axis=0,inplace=True)
oil.head()
# Out:
# 3    City Edition     Sport Discipline             Athlete  NOC Gender  \
# 4  Athens    1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 5  Athens    1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 6  Athens    1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 7  Athens    1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 8  Athens    1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
# 3                       Event Event_gender   Medal
# 4              100m freestyle            M    Gold
# 5              100m freestyle            M  Silver
# 6  100m freestyle for sailors            M  Bronze
# 7  100m freestyle for sailors            M    Gold
# 8  100m freestyle for sailors            M  Silver

# %%
oil.reset_index()
# Out:
# 3      index     City Edition      Sport       Discipline  \
# 0          4   Athens    1896   Aquatics         Swimming
# 1          5   Athens    1896   Aquatics         Swimming
# 2          6   Athens    1896   Aquatics         Swimming
# 3          7   Athens    1896   Aquatics         Swimming
# 4          8   Athens    1896   Aquatics         Swimming
# ...      ...      ...     ...        ...              ...
# 29211  29215  Beijing    2008  Wrestling  Wrestling Gre-R
# 29212  29216  Beijing    2008  Wrestling  Wrestling Gre-R
# 29213  29217  Beijing    2008  Wrestling  Wrestling Gre-R
# 29214  29218  Beijing    2008  Wrestling  Wrestling Gre-R
# 29215  29219  Beijing    2008  Wrestling  Wrestling Gre-R
#
# 3                   Athlete  NOC Gender                       Event  \
# 0             HAJOS, Alfred  HUN    Men              100m freestyle
# 1          HERSCHMANN, Otto  AUT    Men              100m freestyle
# ...

# %%
oil.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'NOC', 'Gender',
#        'Event', 'Event_gender', 'Medal'],
#       dtype='object', name=3)

# %%
lf = oil.Medal.unique()
lf
# Out:
# array(['Gold', 'Silver', 'Bronze'], dtype=object)

# %%
oil.groupby(['Sport','Gender'])['Medal'].nunique()
# Out:
# Sport              Gender
# Aquatics           Men       3
#                    Women     3
# Archery            Men       3
#                    Women     3
# Athletics          Men       3
#                             ..
# Water Motorsports  Men       1
# Weightlifting      Men       3
#                    Women     3
# Wrestling          Men       3
#                    Women     3
# Name: Medal, Length: 69, dtype: int64

# %%
oil.Discipline.unique()
# Out:
# array(['Swimming', 'Athletics', 'Cycling Road', 'Cycling Track',
#        'Fencing', 'Artistic G.', 'Shooting', 'Tennis', 'Weightlifting',
#        'Wrestling Gre-R', 'Water polo', 'Archery', 'Basque Pelota',
#        'Cricket', 'Croquet', 'Jumping', 'Football', 'Golf', 'Polo',
#        'Rowing', 'Rugby', 'Sailing', 'Tug of War', 'Diving', 'Boxing',
#        'Lacrosse', 'Roque', 'Wrestling Free.', 'Hockey', 'Jeu de Paume',
#        'Rackets', 'Figure skating', 'Water Motorspor', 'Dressage',
#        'Eventing', 'Modern Pentath.', 'Vaulting', 'Ice Hockey',
#        'Basketball', 'Canoe / Kayak F', 'Handball', 'Judo', 'Volleyball',
#        'Canoe / Kayak S', 'Synchronized S.', 'Rhythmic G.',
#        'Table Tennis', 'Badminton', 'Baseball', 'Mountain Bike',
#        'Softball', 'Beach volley.', 'Trampoline', 'Taekwondo',
#        'Triathlon', 'BMX'], dtype=object)

# %%
ff = oil.groupby(['City','Gender','Discipline'])['Discipline'].count()
ff.
# Out:
# City       Gender  Discipline
# Amsterdam  Men     Artistic G.      42
#                    Athletics        84
#                    Boxing           24
#                    Cycling Road     12
#                    Cycling Track    27
#                                     ..
# Tokyo      Women   Dressage          1
#                    Fencing          17
#                    Jumping           1
#                    Swimming         42
#                    Volleyball       36
# Name: Discipline, Length: 931, dtype: int64

# %%
oil.City.unique()
# Out:
# array(['Athens', 'Paris', 'St Louis', 'London', 'Stockholm', 'Antwerp',
#        'Amsterdam', 'Los Angeles', 'Berlin', 'Helsinki',
#        'Melbourne / Stockholm', 'Rome', 'Tokyo', 'Mexico', 'Munich',
#        'Montreal', 'Moscow', 'Seoul', 'Barcelona', 'Atlanta', 'Sydney',
#        'Beijing'], dtype=object)
